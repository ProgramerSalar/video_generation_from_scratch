# %%
import torch 

tensor = torch.randn(2, 4, 3, 4, 16)
for i in range(2):
    a = tensor[i:] # 0:, 1:
    # [start:stop:step]
    b = tensor[i::2]
    print(b.shape)
# Out:
# torch.Size([1, 4, 3, 4, 16])
# torch.Size([1, 4, 3, 4, 16])

# %%
unbind_tensor = tensor.unbind(dim=1)
unbind_tensor
# Out:
# (tensor([[[[ 5.1993e-02, -1.0691e-03,  5.5475e-01, -1.3970e+00,  2.5270e-01,
#              3.3275e-01,  7.7914e-02, -1.1249e+00, -9.6920e-01, -1.5527e+00,
#              1.0955e+00, -8.5237e-01, -1.7745e-01,  1.1227e+00,  2.3321e-02,
#             -7.6807e-01],
#            [-7.8568e-01,  3.2649e-01, -3.9177e-01, -1.1150e+00,  2.2974e-02,
#              8.9115e-01,  1.0193e+00,  6.7804e-01, -1.1023e-01, -1.0427e+00,
#             -1.4963e-02, -9.5095e-01, -4.1748e-01,  1.6173e+00,  9.6811e-02,
#             -3.8963e-01],
#            [ 1.9415e+00,  5.0554e-01,  9.7035e-01, -6.7635e-01,  1.7767e+00,
#             -1.0151e+00, -1.6784e+00, -4.6322e-01, -1.3474e-01, -5.4580e-01,
#              1.3858e+00,  1.8877e+00,  7.8110e-02, -6.5979e-01, -5.6155e-01,
#              6.3691e-01],
#            [ 9.7642e-01,  8.9501e-01, -1.9314e+00,  8.4199e-01, -1.5952e+00,
#             -1.4049e+00,  5.2302e-01, -1.3441e+00, -8.8650e-02,  1.1318e-01,
# ...
